# %%
import pandas as pd

# %%
df=pd.read_csv('UNSOLD_PLAYERS.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PLAYER       260 non-null    object
#  1   NATIONALITY  260 non-null    object
#  2   TYPE         260 non-null    object
#  3   BASE PRICE   260 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 8.2+ KB

# %%
df.head(50)
# Out:
#                  PLAYER NATIONALITY           TYPE  BASE PRICE
# 0         Priyansh Arya      Indian         Batter     2000000
# 1       Rohan Kunnummal      Indian         Batter     2000000
# 2           Manan Vohra      Indian         Batter     2000000
# 3        Raj Angad Bawa      Indian    All-Rounder     2000000
# 4         Sarfaraz Khan      Indian    All-Rounder     2000000
# 5        Vivrant Sharma      Indian    All-Rounder     2000000
# 6            Atit Sheth      Indian    All-Rounder     2000000
# 7       Hrithik Shokeen      Indian    All-Rounder     2000000
# 8           Urvil Patel      Indian  Wicket-Keeper     2000000
# 9        Vishnu Solanki      Indian  Wicket-Keeper     2000000
# 10          Ishan Porel      Indian         Bowler     2000000
# 11         Kuldip Yadav      Indian         Bowler     2000000
# 12        Murgan Ashwin      Indian         Bowler     2000000
# 13        Pulkit Narang      Indian         Bowler     2000000
# ...

# %%
df.tail()
# Out:
#                 PLAYER NATIONALITY         TYPE  BASE PRICE
# 255  Kamlesh Nagarkoti      Indian  All-Rounder     3000000
# 256       Basil Thampi      Indian       Bowler     3000000
# 257        Lalit Yadav      Indian       Bowler     3000000
# 258           S Midhun      Indian       Bowler     3000000
# 259  Izharulhuq Naveed    Overseas       Bowler     3000000

# %%
df.isnull().sum()
# Out:
# PLAYER         0
# NATIONALITY    0
# TYPE           0
# BASE PRICE     0
# dtype: int64

# %%
df.describe()
# Out:
#          BASE PRICE
# count  2.600000e+02
# mean   4.025000e+06
# std    4.145560e+06
# min    2.000000e+06
# 25%    2.000000e+06
# 50%    2.000000e+06
# 75%    5.000000e+06
# max    2.000000e+07

# %%
df.shape
# Out:
# (260, 4)

# %%
df.dtypes
# Out:
# PLAYER         object
# NATIONALITY    object
# TYPE           object
# BASE PRICE      int64
# dtype: object

# %%
df['BASE PRICE']=df['BASE PRICE'].astype('float64')

# %%
df.dtypes
# Out:
# PLAYER          object
# NATIONALITY     object
# TYPE            object
# BASE PRICE     float64
# dtype: object

# %%
df['TYPE'].replace(['Batter','Bowler'],[0,1],inplace=True)

# %%
df.head(20)
# Out:
#                 PLAYER NATIONALITY           TYPE  BASE PRICE
# 0        Priyansh Arya      Indian              0   2000000.0
# 1      Rohan Kunnummal      Indian              0   2000000.0
# 2          Manan Vohra      Indian              0   2000000.0
# 3       Raj Angad Bawa      Indian    All-Rounder   2000000.0
# 4        Sarfaraz Khan      Indian    All-Rounder   2000000.0
# 5       Vivrant Sharma      Indian    All-Rounder   2000000.0
# 6           Atit Sheth      Indian    All-Rounder   2000000.0
# 7      Hrithik Shokeen      Indian    All-Rounder   2000000.0
# 8          Urvil Patel      Indian  Wicket-Keeper   2000000.0
# 9       Vishnu Solanki      Indian  Wicket-Keeper   2000000.0
# 10         Ishan Porel      Indian              1   2000000.0
# 11        Kuldip Yadav      Indian              1   2000000.0
# 12       Murgan Ashwin      Indian              1   2000000.0
# 13       Pulkit Narang      Indian              1   2000000.0
# ...

# %%
df=pd.get_dummies(df, columns=['NATIONALITY'])

# %%
df.head()
# Out:
#             PLAYER         TYPE  BASE PRICE  NATIONALITY_Indian  \
# 0    Priyansh Arya            0   2000000.0                True
# 1  Rohan Kunnummal            0   2000000.0                True
# 2      Manan Vohra            0   2000000.0                True
# 3   Raj Angad Bawa  All-Rounder   2000000.0                True
# 4    Sarfaraz Khan  All-Rounder   2000000.0                True
#
#    NATIONALITY_Overseas
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
