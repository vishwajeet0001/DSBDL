# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('income_dataset.csv')

# %%
df
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       67    Private  366425     Doctorate               16
# 1       17    Private  244602          12th                8
# 2       31    Private  174201     Bachelors               13
# 3       58  State-gov  110199       7th-8th                4
# 4       25  State-gov  149248  Some-college               10
# ...    ...        ...     ...           ...              ...
# 43952   52    Private   68982     Bachelors               13
# 43953   19    Private  116562       HS-grad                9
# 43954   30    Private  197947  Some-college               10
# 43955   46    Private   97883     Bachelors               13
# 43956   30    Private  375827       HS-grad                9
#
#            marital-status         occupation    relationship   race  gender  \
# 0                Divorced    Exec-managerial   Not-in-family  White    Male
# 1           Never-married      Other-service       Own-child  White    Male
# ...

# %%
# Group by the categorical variable toh categorical variable h workclass aur numerical h hours per week
G=df.groupby('workclass').agg({'hours-per-week': ['mean', 'median', 'min', 'max', 'std']})
print(G)
# Out:
#                  hours-per-week
#                            mean median min max        std
# workclass
# Federal-gov           41.539720   40.0   4  99   8.876435
# Local-gov             40.892275   40.0   2  99  10.871967
# Never-worked          34.375000   35.0  20  40   6.781013
# Private               40.246150   40.0   1  99  11.263986
# Self-emp-inc          48.608696   50.0   1  99  14.250596
# Self-emp-not-inc      44.335739   40.0   1  99  16.617702
# State-gov             39.052392   40.0   1  99  11.989815
# Without-pay           32.900000   35.0  10  65  16.466553

# %%
#kisi single ka bole mean nikaalne ko
df['age'].mean()
# Out:
# 38.61714857701845

# %%
# 2nd part iris waala
dff = pd.read_csv('Iris.csv')

# %%
dff
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Filter kiya data ko for each species
a=dff[dff['Species'] == 'Iris-setosa'].describe()
b=dff[dff['Species'] == 'Iris-versicolor'].describe()
c=dff[dff['Species'] == 'Iris-virginica'].describe()

print("Summary Statistics for Iris-setosa:")
print(a)
print("\nSummary Statistics for Iris-versicolor:")
print(b)
print("\nSummary Statistics for Iris-virginica:")
print(c)
# Out:
# Summary Statistics for Iris-setosa:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000
#
# Summary Statistics for Iris-versicolor:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# ...
