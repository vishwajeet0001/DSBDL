# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#1
print("Features and their types:")
print(df.dtypes)
# Out:
# Features and their types:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
#2.Create a histogram for each feature
plt.figure(figsize=(10, 6))
for feature in df.columns[:-1]:
    sns.histplot(df[feature], kde=True, label=feature, alpha=0.7)
plt.title('Histograms of Features in Iris Dataset')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
#3 Create a box plot for each feature
plt.figure(figsize=(10, 6))
sns.boxplot(data=df.drop('Species', axis=1))
plt.title('Box Plots of Features in Iris Dataset')
plt.xlabel('Feature')
plt.ylabel('Value')
plt.show()

# %%
# outlier nikal lo IQR se
